# %%
from ultralytics import YOLO
import cv2
import numpy as np
import matplotlib.pyplot as plt
import os

# %% [markdown]
# ## LOAD MODEL

# %%
model = YOLO('./model/client_model/best.pt')
model2 = YOLO('./model/client_model/best.pt')

# %% [markdown]
# ## READ FROM VIDEO

# %%
# video_path = './dataset/Video/Video_2_30_detik.mp4'
# cap = cv2.VideoCapture(video_path)

# %% [markdown]
# ## READ FROM WEBCAM

# %%
cap = cv2.VideoCapture(0)

# %% [markdown]
# ## LICENSE DETECTION

# %%
captured = []
len_file = os.listdir('./license_predict/')
plate = len(len_file)

# %%
def create_detection_frame(frame):
    new_height = int(frame.shape[0] * 0.4)  # 40% dari tinggi frame asli
    new_width = frame.shape[1]  # Lebar sesuai dengan frame asli

    # Hitung koordinat untuk rectangle
    top_left_x = 0
    top_left_y = frame.shape[0] - new_height - int(frame.shape[0] * 0.1)  # Angkat rectangle ke tengah 10%
    bottom_right_x = frame.shape[1]
    bottom_right_y = top_left_y + new_height
    
    cv2.rectangle(frame, (top_left_x, top_left_y), (bottom_right_x, bottom_right_y), (0, 255, 255), thickness=2)
    
    return frame[top_left_y:bottom_right_y, top_left_x:bottom_right_x], top_left_x, top_left_y, bottom_right_x, bottom_right_y

# %%
def detect_objects(frame, model):
    # Lakukan deteksi objek menggunakan model
    result = model.track(frame, persist=True)
    
    if result is not None and result[0].boxes.id is not None:
        track_ids = result[0].boxes.id.int().cpu().tolist()
        boxes = result[0].boxes.xywh.cpu()
        frame_ = result[0].plot()   
        
        return frame_, track_ids, result, boxes
    else:
        return None, None, None, None

# %%
def detect_license_plate(detected_area, model,track_ids, result):
    global captured
    global plate
    # Loop untuk setiap hasil deteksi
    for i, track_id in enumerate(track_ids):
        x1, y1, x2, y2, id, score, class_id = result[0].boxes.data[i].numpy()
        if track_id not in captured and int(class_id) != 2:
            capture_frame = detected_area[int(y1):int(y2), int(x1):int(x2)]
            license_detection = model(capture_frame)[0]
            for detection in license_detection.boxes.data.tolist():
                x1_license, y1_license, x2_license, y2_license, score_license, class_id_license = detection
                if class_id_license == 2:
                    license_frame = capture_frame[int(y1_license):int(y2_license), int(x1_license):int(x2_license)]
                    captured.append(track_id)
                    # Ganti fungsionalitas untuk menyimpan gambar, misalnya:
                    cv2.imwrite(f'./license_predict/{plate}.jpg', license_frame)
                    plate += 1

# %%
def resized_frame(frame):
    ## MENAMPILKAN LIVE
    # Mendapatkan dimensi asli frame
    original_height, original_width = frame.shape[:2]

    # Hitung faktor skala untuk menyesuaikan frame agar muat dalam satu layar laptop
    screen_height = 720  # Misalnya, resolusi layar laptop adalah 720p
    screen_width = 1280  # Misalnya, resolusi layar laptop adalah 1280p
    scale_factor = min(screen_height / original_height, screen_width / original_width)

    # Resize frame sesuai dengan faktor skala
    resized_frame = cv2.resize(frame, None, fx=scale_factor, fy=scale_factor)
    
    return resized_frame

# %%
ret = True

while ret:
    ret, frame = cap.read()
    
    if ret:
        detected_area, top_left_x, top_left_y, bottom_right_x, bottom_right_y = create_detection_frame(frame)
        
        frame_, track_ids, result, boxes = detect_objects(detected_area, model)
        
        if frame_ is not None:
            detect_license_plate(detected_area, model2, track_ids, result)

            # Pastikan untuk mengganti area yang dicrop dengan frame_
            frame[top_left_y:bottom_right_y, top_left_x:bottom_right_x] = frame_
            
            cv2.imshow('frame', resized_frame(frame))
            
            if cv2.waitKey(25) & 0xFF == ord('q'):
                break
        else:
            print("Model tidak mengembalikan hasil yang diharapkan. Lanjutkan ke frame berikutnya.")
            continue  # Lanjutkan ke frame berikutnya jika hasil tidak tersedia
        
cv2.destroyAllWindows()
# Out:
# 0: 256x800 2 Motors, 147.8ms
# Speed: 5.0ms preprocess, 147.8ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 800)
# Model tidak mengembalikan hasil yang diharapkan. Lanjutkan ke frame berikutnya.
#
# 0: 256x800 3 Motors, 99.2ms
# Speed: 4.0ms preprocess, 99.2ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 800)
# Model tidak mengembalikan hasil yang diharapkan. Lanjutkan ke frame berikutnya.
#
# 0: 256x800 3 Motors, 110.3ms
# Speed: 2.5ms preprocess, 110.3ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 800)
# Model tidak mengembalikan hasil yang diharapkan. Lanjutkan ke frame berikutnya.
#
# 0: 256x800 3 Motors, 124.8ms
# Speed: 2.0ms preprocess, 124.8ms inference, 1.5ms postprocess per image at shape (1, 3, 256, 800)
# Model tidak mengembalikan hasil yang diharapkan. Lanjutkan ke frame berikutnya.
#
# 0: 256x800 3 Motors, 109.3ms
# Speed: 0.5ms preprocess, 109.3ms inference, 0.5ms postprocess per image at shape (1, 3, 256, 800)
# Model tidak mengembalikan hasil yang diharapkan. Lanjutkan ke frame berikutnya.
#
# 0: 256x800 3 Motors, 102.2ms
# Speed: 1.0ms preprocess, 102.2ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 800)
# Model tidak mengembalikan hasil yang diharapkan. Lanjutkan ke frame berikutnya.
#
# 0: 256x800 2 Motors, 101.7ms
# Speed: 1.0ms preprocess, 101.7ms inference, 1.5ms postprocess per image at shape (1, 3, 256, 800)
# Model tidak mengembalikan hasil yang diharapkan. Lanjutkan ke frame berikutnya.
#
# 0: 256x800 2 Motors, 94.0ms
# Speed: 2.0ms preprocess, 94.0ms inference, 2.0ms postprocess per image at shape (1, 3, 256, 800)
# Model tidak mengembalikan hasil yang diharapkan. Lanjutkan ke frame berikutnya.
#
# 0: 256x800 2 Motors, 93.2ms
# Speed: 2.0ms preprocess, 93.2ms inference, 2.0ms postprocess per image at shape (1, 3, 256, 800)
# Model tidak mengembalikan hasil yang diharapkan. Lanjutkan ke frame berikutnya.
#
# 0: 256x800 3 Motors, 94.2ms
# Speed: 1.0ms preprocess, 94.2ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 800)
# Model tidak mengembalikan hasil yang diharapkan. Lanjutkan ke frame berikutnya.
#
# 0: 256x800 3 Motors, 94.3ms
# Speed: 2.0ms preprocess, 94.3ms inference, 1.5ms postprocess per image at shape (1, 3, 256, 800)
# Model tidak mengembalikan hasil yang diharapkan. Lanjutkan ke frame berikutnya.
#
# 0: 256x800 2 Motors, 94.7ms
# Speed: 1.0ms preprocess, 94.7ms inference, 2.0ms postprocess per image at shape (1, 3, 256, 800)
# Model tidak mengembalikan hasil yang diharapkan. Lanjutkan ke frame berikutnya.
#
# 0: 256x800 3 Motors, 98.7ms
# Speed: 0.0ms preprocess, 98.7ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 800)
# Model tidak mengembalikan hasil yang diharapkan. Lanjutkan ke frame berikutnya.
#
# 0: 256x800 2 Motors, 94.7ms
# Speed: 1.0ms preprocess, 94.7ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 800)
# Model tidak mengembalikan hasil yang diharapkan. Lanjutkan ke frame berikutnya.
#
# 0: 256x800 2 Motors, 93.2ms
# Speed: 1.0ms preprocess, 93.2ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 800)
# Model tidak mengembalikan hasil yang diharapkan. Lanjutkan ke frame berikutnya.
#
# 0: 256x800 2 Motors, 93.7ms
# Speed: 1.0ms preprocess, 93.7ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 800)
# Model tidak mengembalikan hasil yang diharapkan. Lanjutkan ke frame berikutnya.
#
# 0: 256x800 2 Motors, 95.6ms
# Speed: 1.0ms preprocess, 95.6ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 800)
# Model tidak mengembalikan hasil yang diharapkan. Lanjutkan ke frame berikutnya.
#
# 0: 256x800 1 Motor, 99.7ms
# Speed: 1.0ms preprocess, 99.7ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 800)
# Model tidak mengembalikan hasil yang diharapkan. Lanjutkan ke frame berikutnya.
#
# 0: 256x800 1 Motor, 94.7ms
# Speed: 1.0ms preprocess, 94.7ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 800)
# Model tidak mengembalikan hasil yang diharapkan. Lanjutkan ke frame berikutnya.
#
# 0: 256x800 2 Motors, 91.0ms
# Speed: 2.0ms preprocess, 91.0ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 800)
# Model tidak mengembalikan hasil yang diharapkan. Lanjutkan ke frame berikutnya.
#
# 0: 256x800 1 Mobil, 3 Motors, 92.2ms
# Speed: 1.0ms preprocess, 92.2ms inference, 1.5ms postprocess per image at shape (1, 3, 256, 800)
# Model tidak mengembalikan hasil yang diharapkan. Lanjutkan ke frame berikutnya.
#
# 0: 256x800 1 Motor, 94.2ms
# Speed: 1.0ms preprocess, 94.2ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 800)
#
# 0: 672x800 (no detections), 256.7ms
# Speed: 5.5ms preprocess, 256.7ms inference, 0.0ms postprocess per image at shape (1, 3, 672, 800)
#
# 0: 256x800 1 Motor, 99.2ms
# Speed: 4.5ms preprocess, 99.2ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 800)
#
# 0: 704x800 (no detections), 240.1ms
# Speed: 7.0ms preprocess, 240.1ms inference, 1.0ms postprocess per image at shape (1, 3, 704, 800)
#
# 0: 256x800 1 Motor, 92.9ms
# Speed: 2.0ms preprocess, 92.9ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 800)
#
# 0: 704x800 (no detections), 213.8ms
# Speed: 4.5ms preprocess, 213.8ms inference, 1.0ms postprocess per image at shape (1, 3, 704, 800)
#
# 0: 256x800 1 Motor, 101.8ms
# Speed: 1.5ms preprocess, 101.8ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 800)
#
# 0: 768x800 (no detections), 260.1ms
# Speed: 5.5ms preprocess, 260.1ms inference, 1.0ms postprocess per image at shape (1, 3, 768, 800)
#
# 0: 256x800 1 Motor, 96.9ms
# Speed: 1.5ms preprocess, 96.9ms inference, 1.5ms postprocess per image at shape (1, 3, 256, 800)
#
# 0: 800x704 (no detections), 231.4ms
# Speed: 5.4ms preprocess, 231.4ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 704)
#
# 0: 256x800 1 Motor, 103.8ms
# Speed: 2.5ms preprocess, 103.8ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 800)
#
# 0: 768x800 (no detections), 234.9ms
# Speed: 5.5ms preprocess, 234.9ms inference, 1.0ms postprocess per image at shape (1, 3, 768, 800)
#
# 0: 256x800 1 Motor, 96.7ms
# Speed: 2.0ms preprocess, 96.7ms inference, 2.0ms postprocess per image at shape (1, 3, 256, 800)
#
# 0: 704x800 (no detections), 218.1ms
# Speed: 5.5ms preprocess, 218.1ms inference, 1.0ms postprocess per image at shape (1, 3, 704, 800)
#
# 0: 256x800 1 Motor, 89.2ms
# Speed: 2.0ms preprocess, 89.2ms inference, 2.0ms postprocess per image at shape (1, 3, 256, 800)
#
# 0: 704x800 (no detections), 218.0ms
# Speed: 4.0ms preprocess, 218.0ms inference, 1.0ms postprocess per image at shape (1, 3, 704, 800)
#
# 0: 256x800 1 Mobil, 1 Motor, 94.7ms
# Speed: 2.0ms preprocess, 94.7ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 800)
#
# 0: 768x800 (no detections), 241.2ms
# Speed: 5.0ms preprocess, 241.2ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 800)
#
# 0: 800x512 (no detections), 173.7ms
# Speed: 5.0ms preprocess, 173.7ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 512)
#
# 0: 256x800 1 Mobil, 1 Motor, 95.2ms
# Speed: 1.0ms preprocess, 95.2ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 800)
#
# 0: 800x800 (no detections), 255.2ms
# Speed: 4.5ms preprocess, 255.2ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 800x544 (no detections), 188.1ms
# Speed: 4.0ms preprocess, 188.1ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 544)
#
# 0: 256x800 1 Mobil, 1 Motor, 91.2ms
# Speed: 1.5ms preprocess, 91.2ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 800)
#
# 0: 800x800 (no detections), 237.1ms
# Speed: 6.0ms preprocess, 237.1ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 800x576 (no detections), 196.0ms
# Speed: 4.5ms preprocess, 196.0ms inference, 1.5ms postprocess per image at shape (1, 3, 800, 576)
#
# 0: 256x800 1 Mobil, 1 Motor, 94.2ms
# Speed: 1.0ms preprocess, 94.2ms inference, 2.0ms postprocess per image at shape (1, 3, 256, 800)
#
# 0: 768x800 (no detections), 231.0ms
# Speed: 5.5ms preprocess, 231.0ms inference, 1.0ms postprocess per image at shape (1, 3, 768, 800)
#
# 0: 800x544 (no detections), 169.9ms
# Speed: 4.5ms preprocess, 169.9ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 544)
#
# 0: 256x800 1 Mobil, 1 Motor, 96.9ms
# Speed: 1.0ms preprocess, 96.9ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 800)
#
# 0: 704x800 (no detections), 222.0ms
# Speed: 4.0ms preprocess, 222.0ms inference, 1.0ms postprocess per image at shape (1, 3, 704, 800)
#
# 0: 800x544 (no detections), 180.0ms
# Speed: 5.0ms preprocess, 180.0ms inference, 1.5ms postprocess per image at shape (1, 3, 800, 544)
#
# 0: 256x800 1 Mobil, 95.2ms
# Speed: 2.0ms preprocess, 95.2ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 800)
#
# 0: 800x576 (no detections), 185.4ms
# Speed: 6.0ms preprocess, 185.4ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 576)
#
# 0: 256x800 1 Motor, 98.3ms
# Speed: 2.0ms preprocess, 98.3ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 800)
# Model tidak mengembalikan hasil yang diharapkan. Lanjutkan ke frame berikutnya.
#
# 0: 256x800 1 Mobil, 99.0ms
# Speed: 2.6ms preprocess, 99.0ms inference, 1.5ms postprocess per image at shape (1, 3, 256, 800)
#
# 0: 800x544 (no detections), 177.5ms
# Speed: 4.0ms preprocess, 177.5ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 544)
#
# 0: 256x800 1 Motor, 101.7ms
# Speed: 2.0ms preprocess, 101.7ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 800)
# Model tidak mengembalikan hasil yang diharapkan. Lanjutkan ke frame berikutnya.
#
# 0: 256x800 1 Motor, 101.4ms
# Speed: 1.0ms preprocess, 101.4ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 800)
# Model tidak mengembalikan hasil yang diharapkan. Lanjutkan ke frame berikutnya.
#
# 0: 256x800 1 Mobil, 96.2ms
# Speed: 1.5ms preprocess, 96.2ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 800)
#
# 0: 800x544 (no detections), 174.1ms
# Speed: 3.6ms preprocess, 174.1ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 544)
#
# 0: 256x800 1 Mobil, 1 Motor, 99.7ms
# Speed: 2.0ms preprocess, 99.7ms inference, 2.0ms postprocess per image at shape (1, 3, 256, 800)
#
# 0: 800x544 (no detections), 176.6ms
# Speed: 3.5ms preprocess, 176.6ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 544)
#
# 0: 800x800 (no detections), 247.7ms
# Speed: 4.0ms preprocess, 247.7ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 800)
#
# 0: 256x800 1 Mobil, 1 Motor, 97.3ms
# Speed: 1.5ms preprocess, 97.3ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 800)
#
# 0: 800x544 (no detections), 172.4ms
# Speed: 4.5ms preprocess, 172.4ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 544)
#
# 0: 736x800 (no detections), 237.5ms
# Speed: 7.5ms preprocess, 237.5ms inference, 1.0ms postprocess per image at shape (1, 3, 736, 800)
#
# 0: 256x800 1 Mobil, 1 Motor, 91.7ms
# Speed: 1.0ms preprocess, 91.7ms inference, 0.5ms postprocess per image at shape (1, 3, 256, 800)
#
# 0: 800x544 (no detections), 169.2ms
# Speed: 3.0ms preprocess, 169.2ms inference, 1.0ms postprocess per image at shape (1, 3, 800, 544)
#
# 0: 736x800 (no detections), 227.4ms
# Speed: 5.0ms preprocess, 227.4ms inference, 0.0ms postprocess per image at shape (1, 3, 736, 800)
